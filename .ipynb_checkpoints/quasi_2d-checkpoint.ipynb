# %%
import jax
import jax.numpy as jnp
import jax.scipy.ndimage as jndi
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.colors as mcolors
import matplotlib.cm as cm
from matplotlib.animation import FuncAnimation
from matplotlib.collections import LineCollection

# Force 64-bit precision for physical accuracy
jax.config.update("jax_enable_x64", True)

# %%
plt.rcParams['xtick.labelsize'] = 18
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['legend.fontsize'] = 18
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['axes.titlesize'] = 22
plt.rcParams['figure.titlesize'] = 24

# %%
class AxisymmetricSwimmers2D:
    def __init__(self, positions, angles, dipole_strengths):
        """
        Initialise N axisymmetric dipole microswimmers in a 2D plane.
    
        Parameters
        -----------
        positions : Array, shape (N, 2)
            (x, y) coordinates of each swimmer
        angles : Array, shape (N, )
            Orientation angle (theta) of each swimmer, measured from the x-axis
        dipole_strengths : Array, shape (N, )
            Scalar dipole strength of each swimmer. 
            Positive for pusher, negative for puller.
        """
        self.positions = jnp.asarray(positions, dtype=jnp.float64)
        self.angles = jnp.asarray(angles, dtype=jnp.float64)
        self.dipole_strengths = jnp.asarray(dipole_strengths, dtype=jnp.float64)

    # For dynamic number of swimmers, just in case I would like to have cell death/birth in the future
    @property
    def count(self):
        """Returns the number of swimmers in the system"""
        return self.positions.shape[0]

    def update_states(self, new_positions, new_angles):
        """Updates kinematic states. Dipole strengths are assumed constant."""
        self.positions = new_positions
        self.angles = new_angles

# %%
def build_quasi2d_stokes_solver(Lx, Ly, Lz, Nx, Ny, Nz, mu=1.0, eps=0.1):
    """
    Precomputes the static fluid grids and returns a highly optimised, 
    JIT-compiled pure function to solve the flow field.

    Parameters
    -----------
    Lx, Ly, Lz : Floats
        Dimension of the simulation domain
    Nx, Ny, Nz : Integers
        Number of grid points in each dimension. 
        Should be powers of two for optimal FFT efficiency.
    mu : Float
        Dynamic viscosity
    eps : Float (Default value obtained from Ishimoto et al 2017 PRL)
        Size of Gaussian blob

    Returns
    --------
    solve_flow : JIT-compiled function
        A function to calculate the velocity field of the fluid
    """
    dx, dy, dz = Lx / Nx, Ly / Ny, Lz / Nz
    z_mid = Lz / 2.0
    
    # Precompute all spatial and Fourier grids once
    x = jnp.linspace(0, Lx, Nx, endpoint=False)
    y = jnp.linspace(0, Ly, Ny, endpoint=False)
    z = jnp.linspace(0, Lz, Nz, endpoint=False)
    X, Y, Z = jnp.meshgrid(x, y, z, indexing='ij')
    
    kx = 2 * jnp.pi * jnp.fft.fftfreq(Nx, d=dx)
    ky = 2 * jnp.pi * jnp.fft.fftfreq(Ny, d=dy)
    kz = 2 * jnp.pi * jnp.fft.fftfreq(Nz, d=dz)
    KX, KY, KZ = jnp.meshgrid(kx, ky, kz, indexing='ij')
    
    K2 = KX**2 + KY**2 + KZ**2
    K2_safe = jnp.where(K2 == 0.0, 1.0, K2)

    def _single_swimmer_force(pos_2d, theta, sigma):
        """
        Compute the force density exerted by each swimmer.
    
        Parameters
        -----------
        pos_2d : Array, shape (2, )
            (x, y) coordinates of the swimmer
        theta : Float
            Orientation of the swimmer with respect to the x-axis
        sigma : Float
            Dipole strength, positive for pusher, negative for puller.
    
        Returns
        --------
        force_density : Array, shape (3, Nx, Ny, Nz)
            Force density field due to the swimmer
        """
        px, py = jnp.cos(theta), jnp.sin(theta)
        M_xx, M_xy, M_yy = sigma * px * px, sigma * px * py, sigma * py * py
        
        rx = X - pos_2d[0]
        ry = Y - pos_2d[1]
        rz = Z - z_mid

        # Minimum image convention
        rx -= Lx * jnp.round(rx / Lx)
        ry -= Ly * jnp.round(ry / Ly)
        rz -= Lz * jnp.round(rz / Lz)
        
        r2 = rx**2 + ry**2 + rz**2
        
        prefactor = 1.0 / ((2.0 * jnp.pi)**1.5 * eps**3)
        phi_g = prefactor * jnp.exp(-r2 / (2.0 * eps**2))
        
        f_x = (M_xx * rx + M_xy * ry) * phi_g / (eps**2)
        f_y = (M_xy * rx + M_yy * ry) * phi_g / (eps**2)
        f_z = jnp.zeros_like(f_x)

        force_density = jnp.stack([f_x, f_y, f_z], axis=0)
        
        return force_density
        
    vectorized_spreading = jax.vmap(_single_swimmer_force, in_axes=(0, 0, 0))

    # Compile and return the pure solver function
    @jax.jit
    def solve_flow(positions, angles, sigmas):
        """
        Compute the velocity field due to N microswimmers.
    
        Parameters
        -----------
        positions : Array, shape (N, 2)
            (x, y) coordinates of all swimmers
        angles : Array, shape (N, )
            Orientations of all swimmers with respect to the x-axis
        sigmas : Array, shape (N, )
            Dipole strength of all swimmers, positive for pusher, negative for puller.
    
        Returns
        --------
        u_quasi_2d : Array, shape (2, Nx, Ny)
            Velocity field due to the swimmers in the xy-plane with z at the midpoint.
        """
        all_forces = vectorized_spreading(positions, angles, sigmas)
        total_force = jnp.sum(all_forces, axis=0)
        
        F_hat_x = jnp.fft.fftn(total_force[0])
        F_hat_y = jnp.fft.fftn(total_force[1])
        F_hat_z = jnp.fft.fftn(total_force[2])
        
        k_dot_F_hat = KX * F_hat_x + KY * F_hat_y + KZ * F_hat_z
        
        U_hat_x = (F_hat_x - KX * k_dot_F_hat / K2_safe) / (mu * K2_safe)
        U_hat_y = (F_hat_y - KY * k_dot_F_hat / K2_safe) / (mu * K2_safe)
        
        U_hat_x = U_hat_x.at[0, 0, 0].set(0.0)
        U_hat_y = U_hat_y.at[0, 0, 0].set(0.0)
        
        u_x_3d = jnp.fft.ifftn(U_hat_x).real
        u_y_3d = jnp.fft.ifftn(U_hat_y).real
        
        z_idx = Nz // 2

        u_quasi_2d = jnp.stack([u_x_3d[:, :, z_idx], u_y_3d[:, :, z_idx]], axis=0)
        
        return u_quasi_2d

    # The factory function returns the JIT-compiled function
    return solve_flow

# %%
# =============================================================================
# EXECUTION
# =============================================================================
grid_resolution = 256
grid_limit = 0.05*grid_resolution

solver = build_quasi2d_stokes_solver(Lx=grid_limit, Ly=grid_limit, Lz=grid_limit, Nx=grid_resolution, Ny=grid_resolution, Nz=grid_resolution)

# Define 3 swimmers: X, Y positions
positions = [
    [1.0, 2.0],
    [5.0, 9.0],
    [1.2, 7.2]
]

# Orientations: 0 rad (facing right), pi rad (facing left), pi/4 rad (facing up-right)
angles = [0.0, np.pi, np.pi/4.0]

# Dipole strengths: Pusher (>0) and Puller (<0)
sigmas = [-1.0, -1.0, 1.5] 

swimmers = AxisymmetricSwimmers2D(positions, angles, sigmas)

# Solve the flow field
u_quasi_2d = solver(swimmers.positions, swimmers.angles, swimmers.dipole_strengths)

u_x, u_y = u_quasi_2d
u_mag = jnp.sqrt(u_x**2 + u_y**2)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 10))

x = np.linspace(0, grid_limit, grid_resolution, endpoint=False)
y = np.linspace(0, grid_limit, grid_resolution, endpoint=False)
X, Y = np.meshgrid(x, y)

VMIN = 7e-4
VMAX = 0.8
norm = mcolors.LogNorm(vmin=VMIN, vmax=VMAX)
sm = cm.ScalarMappable(cmap='viridis', norm=norm)
sm.set_array([])
fig.colorbar(sm, ax=ax, pad=0.02, shrink=0.6, label="Magnitude of velocity")

ax.set_xlim(0, grid_limit)
ax.set_ylim(0, grid_limit)
ax.set_xlabel(r'$x$')
ax.set_ylabel(r'$y$')

ax.set_aspect('equal')

# Dictionary to prevent duplicate legend entries
legend_tracker = {"Pusher": False, "Puller": False}

# Plot the positions and orientations of the swimmers as vectors
for i in range(swimmers.count):
    sigma = swimmers.dipole_strengths[i]
    
    # Scale arrow vector components by the absolute dipole strength
    px = np.cos(swimmers.angles[i]) * np.abs(sigma)
    py = np.sin(swimmers.angles[i]) * np.abs(sigma)
    
    # Determine type, color, and assign label
    if sigma > 0:
        color = '#FF2DAA'  # Magenta-ish
        swimmer_type = "Pusher"
    else:
        color = '#FF5A36'  # Orange-ish
        swimmer_type = "Puller"

    # Label the first instance of each type; leave others blank
    if not legend_tracker[swimmer_type]:
        quiver_label = swimmer_type
        legend_tracker[swimmer_type] = True
    else:
        quiver_label = "_"  # Matplotlib ignores labels starting with an underscore
    
    ax.quiver(
        swimmers.positions[i, 0], swimmers.positions[i, 1], 
        px, py, 
        color=color, 
        scale=15,
        scale_units='width',
        zorder=5,
        label=quiver_label
    )

# Add the legend to the axis
ax.legend(loc="upper left", bbox_to_anchor=(1, 1.03))

# Apply the locked 'norm' to the pcolormesh
im = ax.pcolormesh(X, Y, u_mag.T, cmap='viridis', norm=norm, shading='auto', zorder=0)

# Plot Streamlines
ax.streamplot(X, Y, u_x.T, u_y.T, color='white', density=1.2, linewidth=1.0, arrowsize=1.2, zorder=1)

# Formatting
ax.set_title(f"Velocity Flow Field of {swimmers.count:d} Swimmers")

plt.savefig(f"velocity_field_3_swimmers.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# #### Incompressibility Check

# %%
# =============================================================================
# EXECUTION
# =============================================================================
grid_resolution = 256
grid_limit = 0.05*grid_resolution

# Define 3 swimmers: X, Y positions
positions = [
    [1.0, 2.0],
    [5.0, 9.0],
    [1.2, 7.2]
]

# Orientations: 0 rad (facing right), pi rad (facing left), pi/4 rad (facing up-right)
angles = [0.0, np.pi, np.pi/4.0]

# Dipole strengths: Pusher (>0) and Puller (<0)
sigmas = [-1.0, -1.0, 1.5] 

swimmers = AxisymmetricSwimmers2D(positions, angles, sigmas)

Lx = Ly = Lz = grid_limit
Nx = Ny = Nz = grid_resolution
mu = 1
eps = 0.1

dx, dy, dz = Lx / Nx, Ly / Ny, Lz / Nz
z_mid = Lz / 2.0

# Precompute all spatial and Fourier grids once
x = jnp.linspace(0, Lx, Nx, endpoint=False)
y = jnp.linspace(0, Ly, Ny, endpoint=False)
z = jnp.linspace(0, Lz, Nz, endpoint=False)
X, Y, Z = jnp.meshgrid(x, y, z, indexing='ij')

kx = 2 * jnp.pi * jnp.fft.fftfreq(Nx, d=dx)
ky = 2 * jnp.pi * jnp.fft.fftfreq(Ny, d=dy)
kz = 2 * jnp.pi * jnp.fft.fftfreq(Nz, d=dz)
KX, KY, KZ = jnp.meshgrid(kx, ky, kz, indexing='ij')

K2 = KX**2 + KY**2 + KZ**2
K2_safe = jnp.where(K2 == 0.0, 1.0, K2)

def _single_swimmer_force(pos_2d, theta, sigma):
    """
    Compute the force density exerted by each swimmer.

    Parameters
    -----------
    pos_2d : Array, shape (2, )
        (x, y) coordinates of the swimmer
    theta : Float
        Orientation of the swimmer with respect to the x-axis
    sigma : Float
        Dipole strength, positive for pusher, negative for puller.

    Returns
    --------
    force_density : Array, shape (3, Nx, Ny, Nz)
        Force density field due to the swimmer
    """
    px, py = jnp.cos(theta), jnp.sin(theta)
    M_xx, M_xy, M_yy = sigma * px * px, sigma * px * py, sigma * py * py
    
    rx = X - pos_2d[0]
    ry = Y - pos_2d[1]
    rz = Z - z_mid

    # Minimum image convention
    rx -= Lx * jnp.round(rx / Lx)
    ry -= Ly * jnp.round(ry / Ly)
    rz -= Lz * jnp.round(rz / Lz)
    
    r2 = rx**2 + ry**2 + rz**2
    
    prefactor = 1.0 / ((2.0 * jnp.pi)**1.5 * eps**3)
    phi_g = prefactor * jnp.exp(-r2 / (2.0 * eps**2))
    
    f_x = (M_xx * rx + M_xy * ry) * phi_g / (eps**2)
    f_y = (M_xy * rx + M_yy * ry) * phi_g / (eps**2)
    f_z = jnp.zeros_like(f_x)

    force_density = jnp.stack([f_x, f_y, f_z], axis=0)
    
    return force_density
    
vectorized_spreading = jax.vmap(_single_swimmer_force, in_axes=(0, 0, 0))

# Compile and return the pure solver function
@jax.jit
def solve_flow(positions, angles, sigmas):
    """
    Compute the velocity field due to N microswimmers.

    Parameters
    -----------
    positions : Array, shape (N, 2)
        (x, y) coordinates of all swimmers
    angles : Array, shape (N, )
        Orientations of all swimmers with respect to the x-axis
    sigmas : Array, shape (N, )
        Dipole strength of all swimmers, positive for pusher, negative for puller.

    Returns
    --------
    u_quasi_2d : Array, shape (2, Nx, Ny)
        Velocity field due to the swimmers in the xy-plane with z at the midpoint.
    """
    all_forces = vectorized_spreading(positions, angles, sigmas)
    total_force = jnp.sum(all_forces, axis=0)
    
    F_hat_x = jnp.fft.fftn(total_force[0])
    F_hat_y = jnp.fft.fftn(total_force[1])
    F_hat_z = jnp.fft.fftn(total_force[2])
    
    k_dot_F_hat = KX * F_hat_x + KY * F_hat_y + KZ * F_hat_z
    
    U_hat_x = (F_hat_x - KX * k_dot_F_hat / K2_safe) / (mu * K2_safe)
    U_hat_y = (F_hat_y - KY * k_dot_F_hat / K2_safe) / (mu * K2_safe)
    U_hat_z = (F_hat_z - KZ * k_dot_F_hat / K2_safe) / (mu * K2_safe)
    
    U_hat_x = U_hat_x.at[0, 0, 0].set(0.0)
    U_hat_y = U_hat_y.at[0, 0, 0].set(0.0)
    U_hat_z = U_hat_z.at[0, 0, 0].set(0.0)
    
    return U_hat_x, U_hat_y, U_hat_z

U_hat_x, U_hat_y, U_hat_z = solve_flow(
    swimmers.positions, swimmers.angles, swimmers.dipole_strengths
)

div_U = np.asarray(KX * U_hat_x + KY * U_hat_y + KZ * U_hat_z)

print(f"Max divergence is {np.max(np.abs(div_U)):.2e}")
print(f"90th-percentile divergence is {np.percentile(np.abs(div_U), 90):.2e}")
print(f"80th-percentile divergence is {np.percentile(np.abs(div_U), 80):.2e}")
# Out:
# Max divergence is 5.69e-12
# 90th-percentile divergence is 4.58e-16
# 80th-percentile divergence is 9.01e-18

# %% [markdown]
# #### Single Swimmer Far-field Decay Check

# %%
# =============================================================================
# 1. SETUP SINGLE SWIMMER AT THE CENTER
# =============================================================================
# Place one pusher perfectly in the middle of the box, facing right
grid_resolution = 256
grid_limit = 0.05*grid_resolution

Lx = Ly = Lz = grid_limit
Nx = Ny = Nz = grid_resolution

dx, dy, dz = Lx / Nx, Ly / Ny, Lz / Nz
center_pos = jnp.array([[Lx / 2.0, Ly / 2.0]])
angle = jnp.array([0.0])
sigma = jnp.array([1.0])

grid_resolution = 256
grid_limit = 0.05*grid_resolution

swimmer = AxisymmetricSwimmers2D(center_pos, angle, sigma)

solver = build_quasi2d_stokes_solver(Lx=grid_limit, Ly=grid_limit, Lz=grid_limit, Nx=grid_resolution, Ny=grid_resolution, Nz=grid_resolution)

# Run the solver
u_quasi_2d = solver(swimmer.positions, swimmer.angles, swimmer.dipole_strengths)

u_x, u_y = u_quasi_2d

# %%
# =============================================================================
# 2. EXTRACT THE 1D SLICE
# =============================================================================
# Find the integer indices for the center of the grid
mid_idx_x = Nx // 2
mid_idx_y = Ny // 2
mid_idx_z = Nz // 2

# We only want to look at points *in front* of the swimmer to avoid log(0) at r=0.
# Slice from the center + 1 grid point, up to the edge of the box
u_x_slice = u_x[mid_idx_x + 1 :, mid_idx_y]

# Calculate the distance 'r' from the swimmer for these points
r_slice = np.arange(1, len(u_x_slice) + 1) * dx

# =============================================================================
# 3. CALCULATE BEST FIT FOR THE MIDDLE 20 POINTS
# =============================================================================
fit_window = 20
fit_start = 10

# Extract the middle 20 points
r_fit = r_slice[fit_start:fit_start+fit_window]
u_fit = u_x_slice[fit_start:fit_start+fit_window]

# Take the log base 10 of both axes
log_r_fit = np.log10(r_fit)
log_u_fit = np.log10(u_fit)

# Perform linear regression (Degree 1 polynomial)
# m is the gradient (power law exponent), c is the y-intercept
m, c = np.polyfit(log_r_fit, log_u_fit, 1)

# =============================================================================
# 4. PLOT THE RESULTS
# =============================================================================
fig, ax = plt.subplots(1, 1, figsize=(10, 10))

# Plot the full extracted slice
ax.loglog(r_slice, u_x_slice, marker='.', 
          label='Simulated $u_x$', zorder=0)

# Generate the y-values for the line of best fit (reversing the log)
fit_line_y = (10**c) * (r_slice[fit_start:fit_start+2*fit_window]**m)

# Plot the line of best fit over the last 20 points
ax.loglog(r_slice[fit_start:fit_start+2*fit_window], fit_line_y, zorder=2,
          lw=3, label=f'Best fit gradient $m = {m:.2f}$')

# Formatting
ax.set_xlabel(r'$r$')
ax.set_ylabel(r'$u_x$')
ax.set_title('Far-Field Decay of a Single Swimmer')
ax.legend()

plt.savefig(f"far_field_decay_basic.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Swimmers have self-propulsion and rotation due to noise

# %%
class AxisymmetricSwimmers2D:
    def __init__(self, positions, angles, dipole_strengths):
        """
        Initialise N axisymmetric dipole microswimmers in a 2D plane.
        
        Parameters
        -----------
        positions : Array, shape (N, 2)
            (x, y) coordinates of each swimmer
        angles : Array, shape (N, )
            Orientation angle (theta) of each swimmer, measured from the x-axis
        dipole_strengths : Array, shape (N, )
            Scalar dipole strength of each swimmer. 
            Positive for pusher, negative for puller.
        """
        self.positions = jnp.asarray(positions, dtype=jnp.float64)
        self.angles = jnp.asarray(angles, dtype=jnp.float64)
        self.dipole_strengths = jnp.asarray(dipole_strengths, dtype=jnp.float64)

    @property
    def count(self):
        """Returns the number of swimmers in the system"""
        return self.positions.shape[0]

    def update_states(self, new_positions, new_angles):
        """Updates kinematic states. Dipole strengths are assumed constant."""
        self.positions = new_positions
        self.angles = new_angles


def build_quasi2d_stokes_solver(Lx, Ly, Lz, Nx, Ny, Nz, mu=1.0, eps=0.1):
    """
    Precomputes grids and returns a JIT-compiled function to solve the flow field.
    
    Parameters
    -----------
    Lx, Ly, Lz : Floats
        Dimension of the simulation domain
    Nx, Ny, Nz : Integers
        Number of grid points in each dimension. 
        Should be powers of two for optimal FFT efficiency.
    mu : Float
        Dynamic viscosity
    eps : Float
        Size of Gaussian blob

    Returns
    --------
    solve_flow : JIT-compiled function
        A function to calculate the velocity field of the fluid
    """
    dx, dy, dz = Lx / Nx, Ly / Ny, Lz / Nz
    z_mid = Lz / 2.0
    
    x = jnp.linspace(0, Lx, Nx, endpoint=False)
    y = jnp.linspace(0, Ly, Ny, endpoint=False)
    z = jnp.linspace(0, Lz, Nz, endpoint=False)
    X, Y, Z = jnp.meshgrid(x, y, z, indexing='ij')
    
    kx = 2 * jnp.pi * jnp.fft.fftfreq(Nx, d=dx)
    ky = 2 * jnp.pi * jnp.fft.fftfreq(Ny, d=dy)
    kz = 2 * jnp.pi * jnp.fft.fftfreq(Nz, d=dz)
    KX, KY, KZ = jnp.meshgrid(kx, ky, kz, indexing='ij')
    
    K2 = KX**2 + KY**2 + KZ**2
    K2_safe = jnp.where(K2 == 0.0, 1.0, K2)

    def _single_swimmer_force(pos_2d, theta, sigma):
        """
        Compute the force density exerted by each swimmer.
    
        Parameters
        -----------
        pos_2d : Array, shape (2, )
            (x, y) coordinates of the swimmer
        theta : Float
            Orientation of the swimmer with respect to the x-axis
        sigma : Float
            Dipole strength, positive for pusher, negative for puller.
    
        Returns
        --------
        force_density : Array, shape (3, Nx, Ny, Nz)
            Force density field due to the swimmer
        """
        px, py = jnp.cos(theta), jnp.sin(theta)
        M_xx, M_xy, M_yy = sigma * px * px, sigma * px * py, sigma * py * py
        
        rx = X - pos_2d[0]
        ry = Y - pos_2d[1]
        rz = Z - z_mid

        rx -= Lx * jnp.round(rx / Lx)
        ry -= Ly * jnp.round(ry / Ly)
        rz -= Lz * jnp.round(rz / Lz)
        
        r2 = rx**2 + ry**2 + rz**2
        
        prefactor = 1.0 / ((2.0 * jnp.pi)**1.5 * eps**3)
        phi_g = prefactor * jnp.exp(-r2 / (2.0 * eps**2))
        
        f_x = (M_xx * rx + M_xy * ry) * phi_g / (eps**2)
        f_y = (M_xy * rx + M_yy * ry) * phi_g / (eps**2)
        f_z = jnp.zeros_like(f_x)

        return jnp.stack([f_x, f_y, f_z], axis=0)
        
    vectorized_spreading = jax.vmap(_single_swimmer_force, in_axes=(0, 0, 0))

    @jax.jit
    def solve_flow(positions, angles, sigmas):
        """
        Compute the velocity field due to N microswimmers.
    
        Parameters
        -----------
        positions : Array, shape (N, 2)
            (x, y) coordinates of all swimmers
        angles : Array, shape (N, )
            Orientations of all swimmers with respect to the x-axis
        sigmas : Array, shape (N, )
            Dipole strength of all swimmers, positive for pusher, negative for puller.
    
        Returns
        --------
        u_quasi_2d : Array, shape (2, Nx, Ny)
            Velocity field due to the swimmers in the xy-plane with z at the midpoint.
        """
        all_forces = vectorized_spreading(positions, angles, sigmas)
        total_force = jnp.sum(all_forces, axis=0)
        
        F_hat_x = jnp.fft.fftn(total_force[0])
        F_hat_y = jnp.fft.fftn(total_force[1])
        F_hat_z = jnp.fft.fftn(total_force[2])
        
        k_dot_F_hat = KX * F_hat_x + KY * F_hat_y + KZ * F_hat_z
        
        U_hat_x = (F_hat_x - KX * k_dot_F_hat / K2_safe) / (mu * K2_safe)
        U_hat_y = (F_hat_y - KY * k_dot_F_hat / K2_safe) / (mu * K2_safe)
        
        U_hat_x = U_hat_x.at[0, 0, 0].set(0.0)
        U_hat_y = U_hat_y.at[0, 0, 0].set(0.0)
        
        u_x_3d = jnp.fft.ifftn(U_hat_x).real
        u_y_3d = jnp.fft.ifftn(U_hat_y).real
        
        z_idx = Nz // 2
        return jnp.stack([u_x_3d[:, :, z_idx], u_y_3d[:, :, z_idx]], axis=0)

    return solve_flow


def build_trajectory_generator(Lx, Ly, dt, v0=0.1, Dr=0.01):
    """
    Returns a JIT-compiled function that simulates swimmer trajectories over time
    using active self-propulsion and rotational diffusion.

    Parameters
    -----------
    Lx, Ly : Floats
        Dimensions of the simulation domain
    dt : Float
        Time-step
    v0 : Float (Default value obtained from Gemini summary of mammalian sperm)
        Self-propulsion velocity of all swimmers (share the same value)
    Dr : Float (Default value obtained from Gemini summary of mammalian sperm)
        Rotational diffusivity of all swimmers (share the same value)

    Returns
    --------
    wrapper_simulation : JIT-compiled function
        A function which computes the trajectory (position and angle) of 
        all swimmers over time.
    """
    @jax.jit(static_argnames=['num_steps'])
    def wrapper_simulation(initial_positions, initial_angles, num_steps, prng_key):
        """
        The function which computes the trajectory (positions and orientations) of 
        all swimmers over time.
    
        Parameters
        -----------
        initial_positions : Array, shape (N, 2)
            Initial (x, y) coordinates of all swimmers
        initial_angles : Array, shape (N, )
            Initial orientation, as measured from x-axis, of all swimmers
        num_steps : Integer
            Number of timesteps of the simulation
        prng_key: jax.Array
            Starting pseudo-random number generator key
    
        Returns
        --------
        trajectory : tuple of 2 elements
            1st element is the history of positions, a JAX array of shape 
            (num_steps, N, 2).
            2nd element is the history of orientations, a JAX array of shape 
            (num_steps, N).
        """
        def scan_step(carry, _):
            """
            Helper function to be used as an argument for jax.lax.scan. This function 
            will be iterated to update the positions and angles of the swimmers.
        
            Parameters
            -----------
            carry : tuple
                Current (x, y) positions of all swimmers, current orientation of all 
                swimmers, and current random number generator key.
        
            Returns
            --------
            next_carry : tuple
                The value of carry to be used in the next iteration of scan_step.
            outputs : tuple
                The data from the current timestep to be saved, which is (x, y) 
                positions and orientation of all swimmers.
            """
            pos, current_angles, key = carry
            
            # 1. Update positions via active self-propulsion: dx/dt = v0 * p
            px = jnp.cos(current_angles)
            py = jnp.sin(current_angles)
            p = jnp.stack([px, py], axis=-1)
            
            next_pos = pos + v0 * p * dt
            
            # Handle periodic boundaries using modulo arithmetic
            next_pos = next_pos % jnp.array([Lx, Ly])
            
            # 2. Update angles via rotational diffusion: dtheta = sqrt(2*Dr*dt) * xi
            key, subkey = jax.random.split(key)
            noise = jax.random.normal(subkey, shape=current_angles.shape)
            next_angles = current_angles + jnp.sqrt(2.0 * Dr * dt) * noise
            next_angles = next_angles % (2.0 * jnp.pi)
            
            next_carry = (next_pos, next_angles, key)
            outputs = (pos, current_angles)
            return next_carry, outputs

        init_state = (initial_positions, initial_angles, prng_key)
        
        # Run the entire simulation loop natively on hardware
        _, trajectory = jax.lax.scan(scan_step, init_state, None, length=num_steps)
        
        return trajectory

    return wrapper_simulation

# %%
# =============================================================================
# INITIALIZATION & EXECUTION
# =============================================================================
grid_resolution = 256
grid_limit = 12.8
dt = 0.1
total_steps = 100

# Instantiate elements
solver = build_quasi2d_stokes_solver(Lx=grid_limit, Ly=grid_limit, Lz=grid_limit, 
                                    Nx=grid_resolution, Ny=grid_resolution, Nz=grid_resolution)

generate_trajectory = build_trajectory_generator(Lx=grid_limit, Ly=grid_limit, dt=dt)

# Define 3 swimmers: X, Y positions
positions = [
    [1.0, 2.0],
    [5.0, 2.6],
    [1.2, 0.8]
]

# Orientations: 0 rad (facing right), pi rad (facing left), pi/4 rad (facing up-right)
angles = [0.0, np.pi, np.pi/4.0]

sigmas = [-1.0, -1.0, 1.5] 

swimmers = AxisymmetricSwimmers2D(positions, angles, sigmas)

# Initialize JAX random state for the noise
key = jax.random.PRNGKey(42)

# Run the compiled time loop to get historical coordinates
pos_history, angle_history = generate_trajectory(
    swimmers.positions, swimmers.angles, num_steps=total_steps, prng_key=key
)

# %%
# 1. Compile the solver for a SINGLE time step. 
# This makes the execution incredibly fast without exploding memory.
jitted_solver = jax.jit(solver)

# 2. Prepare a list to hold the numpy arrays
u_history_list = []

# 3. Loop through time sequentially
for t in range(total_steps):
    # Calculate the flow for just this specific frame
    u_jax_at_t = jitted_solver(pos_history[t], angle_history[t], swimmers.dipole_strengths)
    
    # IMMEDIATELY convert to numpy. 
    # This offloads it to standard RAM and lets JAX garbage-collect the huge 3D FFT arrays.
    u_history_list.append(np.asarray(u_jax_at_t))

# 4. Stack the resulting frames into a single NumPy array
# Shape will be exactly as before: (num_steps, 2, Nx, Ny)
u_history_numpy = np.stack(u_history_list)

# Calculate the magnitude array for the animation
u_history_mag = np.linalg.norm(u_history_numpy, axis=1)

# %%
# 1. Convert JAX history arrays to NumPy for Matplotlib compatibility
pos_history_np = np.asarray(pos_history)
angle_history_np = np.asarray(angle_history)

# 2. Setup the static figure and grids
fig, ax = plt.subplots(1, 1, figsize=(10, 10))

x = np.linspace(0, grid_limit, grid_resolution, endpoint=False)
y = np.linspace(0, grid_limit, grid_resolution, endpoint=False)
X, Y = np.meshgrid(x, y)

# 3. Configure the static Colorbar (done outside the animation loop)
VMIN = 3e-4
VMAX = 0.8
norm = mcolors.LogNorm(vmin=VMIN, vmax=VMAX)
sm = cm.ScalarMappable(cmap='viridis', norm=norm)
sm.set_array([])
fig.colorbar(sm, ax=ax, pad=0.02, shrink=0.6, label="Magnitude of velocity")

ax.set_xlim(0, grid_limit)
ax.set_ylim(0, grid_limit)
ax.set_xlabel(r'$x$')
ax.set_ylabel(r'$y$')
ax.set_aspect('equal')

# 4. Define the update function for each frame
def update(frame):
    # Clear the axis to remove old streamplots and quivers
    ax.clear()
    
    # Re-apply static formatting
    ax.set_xlim(0, grid_limit)
    ax.set_ylim(0, grid_limit)
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_aspect('equal')
    ax.set_title(f"Velocity Flow Field | Time Step: {dt*frame:.1f}")
    
    # Extract data for the current frame
    u_mag_t = u_history_mag[frame]
    u_x_t = u_history_numpy[frame, 0]
    u_y_t = u_history_numpy[frame, 1]
    
    # Redraw the background velocity magnitude heatmap
    ax.pcolormesh(X, Y, u_mag_t.T, cmap='viridis', norm=norm, shading='auto', zorder=0)
    
    # Redraw the streamlines
    ax.streamplot(X, Y, u_x_t.T, u_y_t.T, color='white', density=1.2, 
                  linewidth=1.0, arrowsize=1.2, zorder=1)
    
    # Dictionary to prevent duplicate legend entries
    legend_tracker = {"Pusher": False, "Puller": False}
    
    # Redraw the swimmers for the current frame
    for i in range(swimmers.count):
        sigma = swimmers.dipole_strengths[i]
        current_angle = angle_history_np[frame, i]
        current_pos_x = pos_history_np[frame, i, 0]
        current_pos_y = pos_history_np[frame, i, 1]
        
        # Scale arrow vector components by the absolute dipole strength
        px = np.cos(current_angle) * np.abs(sigma)
        py = np.sin(current_angle) * np.abs(sigma)
        
        if sigma > 0:
            color = '#FF2DAA'  # Magenta-ish
            swimmer_type = "Pusher"
        else:
            color = '#FF5A36'  # Orange-ish
            swimmer_type = "Puller"

        if not legend_tracker[swimmer_type]:
            quiver_label = swimmer_type
            legend_tracker[swimmer_type] = True
        else:
            quiver_label = "_"
        
        ax.quiver(
            current_pos_x, current_pos_y, 
            px, py, 
            color=color, 
            scale=15,
            scale_units='width',
            zorder=5,
            label=quiver_label
        )
        
    # Re-add the legend

# 6. Create the animation
ani = FuncAnimation(fig, update, frames=total_steps, interval=50, blit=False)

# 7. Save the animation
output_filename = "3_swimmers_flow_field.mp4"
ani.save(output_filename, writer='ffmpeg', fps=10, dpi=300)

# %% [markdown]
# #### Mean Squared Displacement Check: The Dry Limit

# %%
Lx = Ly = 12.8
dt = 0.1
v0 = 0.1
Dr = 0.01

@jax.jit(static_argnames=['num_steps'])
def wrapper_simulation(initial_positions, initial_angles, num_steps, prng_key):
    """
    The function which computes the trajectory (positions and orientations) of 
    all swimmers over time.

    Parameters
    -----------
    initial_positions : Array, shape (N, 2)
        Initial (x, y) coordinates of all swimmers
    initial_angles : Array, shape (N, )
        Initial orientation, as measured from x-axis, of all swimmers
    num_steps : Integer
        Number of timesteps of the simulation
    prng_key: jax.Array
        Starting pseudo-random number generator key

    Returns
    --------
    trajectory : tuple of 2 elements
        1st element is the history of positions, a JAX array of shape 
        (num_steps, N, 2).
        2nd element is the history of orientations, a JAX array of shape 
        (num_steps, N).
    """
    def scan_step(carry, _):
        """
        Helper function to be used as an argument for jax.lax.scan. This function 
        will be iterated to update the positions and angles of the swimmers.
    
        Parameters
        -----------
        carry : tuple
            Current (x, y) positions of all swimmers, current orientation of all 
            swimmers, and current random number generator key.
    
        Returns
        --------
        next_carry : tuple
            The value of carry to be used in the next iteration of scan_step.
        outputs : tuple
            The data from the current timestep to be saved, which is (x, y) 
            positions and orientation of all swimmers.
        """
        pos, current_angles, key = carry
        
        # 1. Update positions via active self-propulsion: dx/dt = v0 * p
        px = jnp.cos(current_angles)
        py = jnp.sin(current_angles)
        p = jnp.stack([px, py], axis=-1)
        
        next_pos = pos + v0 * p * dt
        
        # 2. Update angles via rotational diffusion: dtheta = sqrt(2*Dr*dt) * xi
        key, subkey = jax.random.split(key)
        noise = jax.random.normal(subkey, shape=current_angles.shape)
        next_angles = current_angles + jnp.sqrt(2.0 * Dr * dt) * noise
        next_angles = next_angles % (2.0 * jnp.pi)
        
        next_carry = (next_pos, next_angles, key)
        outputs = (pos, current_angles)
        return next_carry, outputs

    init_state = (initial_positions, initial_angles, prng_key)
    
    # Run the entire simulation loop natively on hardware
    _, trajectory = jax.lax.scan(scan_step, init_state, None, length=num_steps)
    
    return trajectory

num_swimmers = 1000
total_time = int(2e4)
time_array = np.arange(0, total_time, dt)
num_steps = int(total_time / dt)

key = jax.random.PRNGKey(42)
key_1, key_2 = jax.random.split(key)
initial_angles = jax.random.uniform(key_1, shape=(num_swimmers, ), minval=0.0, maxval=2*jnp.pi, )
initial_pos = jnp.zeros((num_swimmers, 2))

trajectory = wrapper_simulation(initial_pos, initial_angles, num_steps, key_2)
pos_history = np.asarray(trajectory[0])
squared_displacements = np.sum(pos_history**2, axis=2)

msd = np.mean(squared_displacements, axis=1)
msd_theoretical = (2 * v0**2 / Dr**2) * (Dr * time_array - 1 + np.exp(-Dr * time_array))

# %%
# =============================================================================
# 5. PLOT THE LOG-LOG GRAPH
# =============================================================================
plt.figure(figsize=(10, 10))

# Plot simulated and theoretical MSD
# Skip the first element because log(0) is undefined
plt.loglog(time_array[1:], msd[1:], 'o', label='Simulated MSD')
plt.loglog(time_array[1:], msd_theoretical[1:], '--', linewidth=3, label='Analytical MSD')

# --- Guide Lines for Slopes ---
# Ballistic regime guide line (Slope = 2) at early times
guide_ballistic = (v0**2) * (time_array[1:]**2)
plt.loglog(time_array[1:], guide_ballistic, ':', linewidth=4, 
           label=r'Ballistic Regime $\langle \Delta r^2 \rangle \propto t^2$')

# Diffusive regime guide line (Slope = 1) at late times
guide_diffusive = 2 * v0**2 * time_array[1:] / Dr
plt.loglog(time_array[1:], guide_diffusive, '-.', linewidth=4, 
           label=r'Diffusive Regime $\langle \Delta r^2 \rangle \propto t$')

# Formatting
plt.xlabel(r'$t$')
plt.ylabel(r'$\langle \Delta r^2 \rangle$')
plt.title('ABP Verification: Ballistic-to-Diffusive Crossover')
plt.legend()

plt.savefig(f"ballistic_diffusive_abp.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
angle_history_np = np.asarray(trajectory[1]) # Shape: (total_steps, N_swimmers)

# 5. Calculate Mean Squared Angular Displacement (MSAD)
# First, we unwrap the angles to remove the 0 -> 2*pi modulo jumps
unwrapped_angles = np.unwrap(angle_history_np, axis=0)

# Calculate angular displacement from t=0
delta_theta = unwrapped_angles - unwrapped_angles[0, :]

# Square the displacements and ensemble-average across all 1000 swimmers
msad = np.mean(delta_theta**2, axis=1)

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 10), layout='constrained')

theoretical_msad = 2.0 * 0.01 * time_array

ax.plot(time_array, msad, linewidth=2.5, label='Simulation MSAD Ensemble Average')
ax.plot(time_array, theoretical_msad, linestyle='--', linewidth=2, label=r'Analytical MSAD')

ax.set_title("ABP Verification: Angular Diffusion")
ax.set_xlabel(r"$t$")
ax.set_ylabel(r"$\langle \Delta\theta^2 \rangle$")
ax.legend()

plt.savefig(f"msad_verification_abp.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Couple ABP with Stokes Flow

# %%
class AxisymmetricSwimmers2D:
    def __init__(self, positions, angles, dipole_strengths):
        """
        Initialise N axisymmetric dipole microswimmers in a 2D plane.
    
        Parameters
        ----------
        positions : Array, shape (N, 2)
            (x, y) coordinates of each swimmer
        angles : Array, shape (N, )
            Orientation angle (theta) of each swimmer, measured from the x-axis
        dipole_strengths : Array, shape (N, )
            Scalar dipole strength of each swimmer. 
            Positive for pusher, negative for puller.
        """
        self.positions = jnp.asarray(positions, dtype=jnp.float64)
        self.angles = jnp.asarray(angles, dtype=jnp.float64)
        self.dipole_strengths = jnp.asarray(dipole_strengths, dtype=jnp.float64)

    # For dynamic number of swimmers, just in case I would like to have cell death/birth in the future
    @property
    def count(self):
        """Returns the number of swimmers in the system"""
        return self.positions.shape[0]

    def update_states(self, new_positions, new_angles):
        """Updates kinematic states. Dipole strengths are assumed constant."""
        self.positions = new_positions
        self.angles = new_angles

# %% [markdown]
# Note: `vectorized_spreading` is removed here due to memory issues when the number of swimmers is large. This is because
# `jax.vmap` will allocate an intermediate tensor of shape `[N, 3, Nx, Ny, Nz]` in memory, which is massive when `N` is large.
# Then, it calculates the entries of the massive tensor, before squashing down the massive tensor to one of shape `[3, Nx, Ny, Nz]`
# via summation along `axis=0`.
#
# Instead, we make use of `jax.lax.scan`, which uses a helper function (let's call it `scan_step`) as an argument. `scan_step` is a
# helper function which updates a variable `carry`, at each iteration. `scan_step` gives two outputs:
# 1) `next_carry`: The updated value of the variable `carry`. It has a shape of `[3, Nx, Ny, Nz]`
# 2) `history_carry`: The history of all the values of the variable `carry`, for all iterations. It has a shape of `[N, 3, Nx, Ny, Nz]`.
# The hack used here is to set `history_carry` as `None`. In that way, no massive tensors are created. Only an updating `[3, Nx, Ny, Nz]`
# tensor is created. Hence, we can bypass the memory issues associated with large `N`.

# %%
def build_quasi2d_stokes_solver(Lx, Ly, Lz, Nx, Ny, Nz, mu=1.0, eps=0.1):
    """
    Precomputes grids and returns a JIT-compiled function to solve the flow field.
    
    Parameters
    -----------
    Lx, Ly, Lz : Floats
        Dimension of the simulation domain
    Nx, Ny, Nz : Integers
        Number of grid points in each dimension. 
        Should be powers of two for optimal FFT efficiency.
    mu : Float
        Dynamic viscosity
    eps : Float
        Size of Gaussian blob

    Returns
    --------
    solve_flow : JIT-compiled function
        A function to calculate the velocity field of the fluid
    """
    dx, dy, dz = Lx / Nx, Ly / Ny, Lz / Nz
    z_mid = Lz / 2.0
    
    x = jnp.linspace(0, Lx, Nx, endpoint=False)
    y = jnp.linspace(0, Ly, Ny, endpoint=False)
    z = jnp.linspace(0, Lz, Nz, endpoint=False)
    X, Y, Z = jnp.meshgrid(x, y, z, indexing='ij')
    
    kx = 2 * jnp.pi * jnp.fft.fftfreq(Nx, d=dx)
    ky = 2 * jnp.pi * jnp.fft.fftfreq(Ny, d=dy)
    kz = 2 * jnp.pi * jnp.fft.fftfreq(Nz, d=dz)
    KX, KY, KZ = jnp.meshgrid(kx, ky, kz, indexing='ij')
    
    K2 = KX**2 + KY**2 + KZ**2
    K2_safe = jnp.where(K2 == 0.0, 1.0, K2)

    def _single_swimmer_force(pos_2d, theta, sigma):
        """
        Compute the force density exerted by each swimmer.
    
        Parameters
        -----------
        pos_2d : Array, shape (2, )
            (x, y) coordinates of the swimmer
        theta : Float
            Orientation of the swimmer with respect to the x-axis
        sigma : Float
            Dipole strength, positive for pusher, negative for puller.
    
        Returns
        --------
        force_density : Array, shape (3, Nx, Ny, Nz)
            Force density field due to the swimmer
        """
        px, py = jnp.cos(theta), jnp.sin(theta)
        M_xx, M_xy, M_yy = sigma * px * px, sigma * px * py, sigma * py * py
        
        rx, ry, rz = X - pos_2d[0], Y - pos_2d[1], Z - z_mid

        rx -= Lx * jnp.round(rx / Lx)
        ry -= Ly * jnp.round(ry / Ly)
        rz -= Lz * jnp.round(rz / Lz)
        
        r2 = rx**2 + ry**2 + rz**2
        
        prefactor = 1.0 / ((2.0 * jnp.pi)**1.5 * eps**3)
        phi_g = prefactor * jnp.exp(-r2 / (2.0 * eps**2))
        
        f_x = (M_xx * rx + M_xy * ry) * phi_g / (eps**2)
        f_y = (M_xy * rx + M_yy * ry) * phi_g / (eps**2)
        f_z = jnp.zeros_like(f_x)

        return jnp.stack([f_x, f_y, f_z], axis=0)

    @jax.jit
    def solve_flow(positions, angles, sigmas):
        """
        Compute the velocity flow field due to N microswimmers.
        Linear interpolation was used to find velocity away from grid points.
    
        Parameters
        -----------
        positions : Array, shape (N, 2)
            (x, y) coordinates of all swimmers
        angles : Array, shape (N, )
            Orientations of all swimmers with respect to the x-axis
        sigmas : Array, shape (N, )
            Dipole strength of all swimmers, positive for pusher, negative for puller.
    
        Returns
        --------
        u_fluid : Array, shape (N, 2)
            The linear velocity experienced by each swimmer due to background flow.
        Omega_fluid : Array, shape (N, )
            The angular velocity experienced by each swimmer due to background flow.
        u_grid_2d : Array, shape (2, Nx, Ny)
            The velocity flow field due to all swimmers at the grid points.
        """
        def add_swimmer_force(accumulated_force, i):
            """
            Calculates force for swimmer i and adds it to the running total.
    
            Parameters
            -----------
            accumulated_force : Array, shape (3, Nx, Ny, Nz)
                Total force on the fluid due to all microswimmers accounted for thus far 
                (index 0 to i-1) at the current iteration.
            i : Integer
                Index of the swimmer to be accounted for in the current iteration.
        
            Returns
            --------
            new_force : Array, shape (3, Nx, Ny, Nz)
                The updated accumulated force after considering swimmer of index i.
            None : This is supposed to be the history of accumulated force. Not needed 
            here. Left `None` for memory management.
            """
            new_force = accumulated_force + _single_swimmer_force(positions[i], angles[i], sigmas[i])
            return new_force, None

        # Initialize an empty grid of zeros
        initial_force_grid = jnp.zeros((3, Nx, Ny, Nz))
        
        # Scan over all swimmers (0 to N-1), accumulating the force in-place
        total_force, _ = jax.lax.scan(
            add_swimmer_force, 
            initial_force_grid, 
            jnp.arange(positions.shape[0])
        )
        
        F_hat_x = jnp.fft.fftn(total_force[0])
        F_hat_y = jnp.fft.fftn(total_force[1])
        F_hat_z = jnp.fft.fftn(total_force[2])
        
        k_dot_F_hat = KX * F_hat_x + KY * F_hat_y + KZ * F_hat_z
        
        U_hat_x = (F_hat_x - KX * k_dot_F_hat / K2_safe) / (mu * K2_safe)
        U_hat_y = (F_hat_y - KY * k_dot_F_hat / K2_safe) / (mu * K2_safe)
        
        U_hat_x = U_hat_x.at[0, 0, 0].set(0.0)
        U_hat_y = U_hat_y.at[0, 0, 0].set(0.0)
        
        # Calculate Vorticity in Fourier Space
        Vort_hat_z = 1j * KX * U_hat_y - 1j * KY * U_hat_x
        
        u_x_3d = jnp.fft.ifftn(U_hat_x).real
        u_y_3d = jnp.fft.ifftn(U_hat_y).real
        vort_z_3d = jnp.fft.ifftn(Vort_hat_z).real
        
        # Slice at the mid-plane
        z_idx = Nz // 2
        u_x_2d = u_x_3d[:, :, z_idx]
        u_y_2d = u_y_3d[:, :, z_idx]
        vort_z_2d = vort_z_3d[:, :, z_idx]

        # Interpolate grid values to particle positions
        # Convert physical coordinates to fractional grid indices
        x_idx = positions[:, 0] / dx
        y_idx = positions[:, 1] / dy
        coords = jnp.stack([x_idx, y_idx], axis=0)
        
        # order=1 ensures bilinear interpolation, mode='wrap' handles PBCs perfectly
        u_fluid_x = jndi.map_coordinates(u_x_2d, coords, order=1, mode='wrap')
        u_fluid_y = jndi.map_coordinates(u_y_2d, coords, order=1, mode='wrap')
        vort_fluid_z = jndi.map_coordinates(vort_z_2d, coords, order=1, mode='wrap')
        
        u_fluid = jnp.stack([u_fluid_x, u_fluid_y], axis=-1)
        
        # By Faxen's Law 
        omega_fluid = 0.5 * vort_fluid_z

        u_grid_2d = jnp.stack([u_x_2d, u_y_2d], axis=0)

        return u_fluid, omega_fluid, u_grid_2d

    return solve_flow

# %%
def build_trajectory_generator(Lx, Ly, dt, solve_flow_fn, sigmas, v0=0.1, Dr=0.01):
    """
    Returns a JIT-compiled function that simulates swimmer trajectories over time
    using active self-propulsion, rotational diffusion, AND hydrodynamic coupling.

    Parameters
    -----------
    Lx, Ly : Floats
        Dimensions of the simulation domain
    dt : Float
        Time-step
    solve_flow_fn : JIT-compiled function
        Returns linear and angular velocity of a rigid particle due to background flow
    sigmas : Array, shape (N, )
        Dipole strength of all swimmers, positive for pusher, negative for puller.
    v0 : Float
        Self-propulsion velocity of all swimmers (share the same value)
    Dr : Float
        Rotational diffusivity of all swimmers (share the same value)

    Returns
    --------
    wrapper_simulation : JIT-compiled function
        A function which computes the trajectory (position and angle) of 
        all swimmers over time.
    """
    @jax.jit(static_argnames=['num_steps'])
    def wrapper_simulation(initial_positions, initial_angles, num_steps, prng_key):
        """
        The function which computes the trajectory (positions and orientations) of 
        all swimmers over time.
    
        Parameters
        -----------
        initial_positions : Array, shape (N, 2)
            Initial (x, y) coordinates of all swimmers
        initial_angles : Array, shape (N, )
            Initial orientation, as measured from x-axis, of all swimmers
        num_steps : Integer
            Number of timesteps of the simulation
        prng_key: jax.Array
            Starting pseudo-random number generator key
    
        Returns
        --------
        trajectory : tuple of 2 elements
            1st element is the history of positions, a JAX array of shape 
            (num_steps, N, 2).
            2nd element is the history of orientations, a JAX array of shape 
            (num_steps, N).
        """
        def scan_step(carry, _):
            """
            Helper function to be used as an argument for jax.lax.scan. This function 
            will be iterated to update the positions and angles of the swimmers.
        
            Parameters
            -----------
            carry : tuple
                Current (x, y) positions of all swimmers, current orientation of all 
                swimmers, and current random number generator key.
        
            Returns
            --------
            next_carry : tuple
                The value of carry to be used in the next iteration of scan_step.
            outputs : tuple
                The data from the current timestep to be saved, which is (x, y) 
                positions and orientation of all swimmers.
            """
            pos, current_angles, key = carry
            
            # Get fluid flow and vorticity at current particle positions
            u_fluid, omega_fluid, _ = solve_flow_fn(pos, current_angles, sigmas)
            
            # 1. Update positions (v_propulsion + v_fluid)
            px = jnp.cos(current_angles)
            py = jnp.sin(current_angles)
            p = jnp.stack([px, py], axis=-1)
            
            next_pos = pos + (v0 * p + u_fluid) * dt
            next_pos = next_pos % jnp.array([Lx, Ly])
            
            # 2. Update angles (Omega_noise + Vorticity)
            key, subkey = jax.random.split(key)
            noise = jax.random.normal(subkey, shape=current_angles.shape)
            
            next_angles = current_angles + jnp.sqrt(2.0 * Dr * dt) * noise + omega_fluid * dt
            next_angles = next_angles % (2.0 * jnp.pi)
            
            next_carry = (next_pos, next_angles, key)
            outputs = (pos, current_angles)
            return next_carry, outputs

        init_state = (initial_positions, initial_angles, prng_key)
        _, trajectory = jax.lax.scan(scan_step, init_state, None, length=num_steps)
        
        return trajectory

    return wrapper_simulation

# %%
grid_resolution = 256
grid_limit = 12.8
dt = 0.1
total_steps = 1000

# 1. Instantiate the coupled solvers
solver = build_quasi2d_stokes_solver(
    Lx=grid_limit, Ly=grid_limit, Lz=grid_limit, 
    Nx=grid_resolution, Ny=grid_resolution, Nz=grid_resolution
)

sigmas_array = jnp.array([-1.0, -1.0, 1.5]) 
generate_trajectory = build_trajectory_generator(
    Lx=grid_limit, Ly=grid_limit, dt=dt, 
    solve_flow_fn=solver, sigmas=sigmas_array
)

# 2. Define 3 swimmers
positions = [
    [1.0, 3.0],
    [6.0, 10.0],
    [2.2, 8.2]
]
angles = [0.0, np.pi, np.pi/4.0]
swimmers = AxisymmetricSwimmers2D(positions, angles, sigmas_array)

# Initialize JAX random state for Brownian noise
key = jax.random.PRNGKey(42)

# =============================================================================
# TRAJECTORY GENERATION
# =============================================================================
print("Generating trajectory...")
pos_history, angle_history = generate_trajectory(
    swimmers.positions, swimmers.angles, num_steps=total_steps, prng_key=key
)

# Convert JAX trajectory arrays to NumPy immediately
pos_history_np = np.asarray(pos_history)
angle_history_np = np.asarray(angle_history)

# =============================================================================
# FLOW FIELD POST-PROCESSING
# =============================================================================
u_history_list = []

for t in range(total_steps):
    # Extract the full 2D grid from the 3rd output
    _, _, u_grid_jax = solver(pos_history_np[t], angle_history_np[t], swimmers.dipole_strengths)
    u_history_list.append(np.asarray(u_grid_jax))

    if t % 10 == 0:
        print(f"Calculating flow field at iteration {t:d}")

# Shape: (num_steps, 2, Nx, Ny)
u_history_numpy = np.stack(u_history_list)

# Shape: (num_steps, Nx, Ny)
u_history_mag = np.linalg.norm(u_history_numpy, axis=1)
# Out:
# Generating trajectory...
# Calculating flow field at iteration 0
# Calculating flow field at iteration 10
# Calculating flow field at iteration 20
# Calculating flow field at iteration 30
# Calculating flow field at iteration 40
# Calculating flow field at iteration 50
# Calculating flow field at iteration 60
# Calculating flow field at iteration 70
# Calculating flow field at iteration 80
# Calculating flow field at iteration 90
# Calculating flow field at iteration 100
# Calculating flow field at iteration 110
# Calculating flow field at iteration 120
# Calculating flow field at iteration 130
# Calculating flow field at iteration 140
# Calculating flow field at iteration 150
# Calculating flow field at iteration 160
# Calculating flow field at iteration 170
# Calculating flow field at iteration 180
# Calculating flow field at iteration 190
# Calculating flow field at iteration 200
# Calculating flow field at iteration 210
# Calculating flow field at iteration 220
# Calculating flow field at iteration 230
# Calculating flow field at iteration 240
# Calculating flow field at iteration 250
# Calculating flow field at iteration 260
# Calculating flow field at iteration 270
# Calculating flow field at iteration 280
# Calculating flow field at iteration 290
# Calculating flow field at iteration 300
# Calculating flow field at iteration 310
# Calculating flow field at iteration 320
# Calculating flow field at iteration 330
# Calculating flow field at iteration 340
# Calculating flow field at iteration 350
# Calculating flow field at iteration 360
# Calculating flow field at iteration 370
# Calculating flow field at iteration 380
# Calculating flow field at iteration 390
# Calculating flow field at iteration 400
# Calculating flow field at iteration 410
# Calculating flow field at iteration 420
# Calculating flow field at iteration 430
# Calculating flow field at iteration 440
# Calculating flow field at iteration 450
# Calculating flow field at iteration 460
# Calculating flow field at iteration 470
# Calculating flow field at iteration 480
# Calculating flow field at iteration 490
# Calculating flow field at iteration 500
# Calculating flow field at iteration 510
# Calculating flow field at iteration 520
# Calculating flow field at iteration 530
# Calculating flow field at iteration 540
# Calculating flow field at iteration 550
# Calculating flow field at iteration 560
# Calculating flow field at iteration 570
# Calculating flow field at iteration 580
# Calculating flow field at iteration 590
# Calculating flow field at iteration 600
# Calculating flow field at iteration 610
# Calculating flow field at iteration 620
# Calculating flow field at iteration 630
# Calculating flow field at iteration 640
# Calculating flow field at iteration 650
# Calculating flow field at iteration 660
# Calculating flow field at iteration 670
# Calculating flow field at iteration 680
# Calculating flow field at iteration 690
# Calculating flow field at iteration 700
# Calculating flow field at iteration 710
# Calculating flow field at iteration 720
# Calculating flow field at iteration 730
# Calculating flow field at iteration 740
# Calculating flow field at iteration 750
# Calculating flow field at iteration 760
# Calculating flow field at iteration 770
# Calculating flow field at iteration 780
# Calculating flow field at iteration 790
# Calculating flow field at iteration 800
# Calculating flow field at iteration 810
# Calculating flow field at iteration 820
# Calculating flow field at iteration 830
# Calculating flow field at iteration 840
# Calculating flow field at iteration 850
# Calculating flow field at iteration 860
# Calculating flow field at iteration 870
# Calculating flow field at iteration 880
# Calculating flow field at iteration 890
# Calculating flow field at iteration 900
# Calculating flow field at iteration 910
# Calculating flow field at iteration 920
# Calculating flow field at iteration 930
# Calculating flow field at iteration 940
# Calculating flow field at iteration 950
# Calculating flow field at iteration 960
# Calculating flow field at iteration 970
# Calculating flow field at iteration 980
# Calculating flow field at iteration 990

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 10))

x = np.linspace(0, grid_limit, grid_resolution, endpoint=False)
y = np.linspace(0, grid_limit, grid_resolution, endpoint=False)
X, Y = np.meshgrid(x, y, indexing='ij')

VMIN = 3e-4
VMAX = 0.8
norm = mcolors.LogNorm(vmin=VMIN, vmax=VMAX)
sm = cm.ScalarMappable(cmap='viridis', norm=norm)
sm.set_array([])
fig.colorbar(sm, ax=ax, pad=0.02, shrink=0.6, label="Magnitude of velocity")

def update(frame):
    ax.clear()
    
    # Static formatting
    ax.set_xlim(0, grid_limit)
    ax.set_ylim(0, grid_limit)
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_aspect('equal')
    ax.set_title(f"Active Brownian Particles in Stokes Flow | Time Step: {dt*frame:.1f}")
    
    u_mag_t = u_history_mag[frame]
    u_x_t = u_history_numpy[frame, 0]
    u_y_t = u_history_numpy[frame, 1]
    
    # Note: Because of indexing='ij', we transpose (.T) for Matplotlib
    ax.pcolormesh(X.T, Y.T, u_mag_t.T, cmap='viridis', norm=norm, shading='auto', zorder=0)
    ax.streamplot(X.T, Y.T, u_x_t.T, u_y_t.T, color='white', density=1.2, 
                  linewidth=1.0, arrowsize=1.2, zorder=1)
    
    legend_tracker = {"Pusher": False, "Puller": False}
    
    for i in range(swimmers.count):
        sigma = swimmers.dipole_strengths[i]
        current_angle = angle_history_np[frame, i]
        current_pos_x = pos_history_np[frame, i, 0]
        current_pos_y = pos_history_np[frame, i, 1]
        
        px = np.cos(current_angle) * np.abs(sigma)
        py = np.sin(current_angle) * np.abs(sigma)
        
        if sigma > 0:
            color = '#FF2DAA'
            swimmer_type = "Pusher"
        else:
            color = '#FF5A36'
            swimmer_type = "Puller"

        quiver_label = swimmer_type if not legend_tracker[swimmer_type] else "_"
        legend_tracker[swimmer_type] = True
        
        ax.quiver(
            current_pos_x, current_pos_y, 
            px, py, 
            color=color, 
            scale=15,
            scale_units='width',
            zorder=5,
            label=quiver_label
        )
        
    ax.legend(loc="upper left", bbox_to_anchor=(1, 1.03))

ani = FuncAnimation(fig, update, frames=total_steps, interval=50, blit=False)
output_filename = "abp_hydrodynamic_coupling.mp4"
ani.save(output_filename, writer='ffmpeg', fps=100, dpi=300)

# %% [markdown]
# #### Single Swimmer Signature Test

# %%
grid_resolution = 256
grid_limit = 12.8

# 1. Instantiate the solver
solver = build_quasi2d_stokes_solver(
    Lx=grid_limit, Ly=grid_limit, Lz=grid_limit, 
    Nx=grid_resolution, Ny=grid_resolution, Nz=grid_resolution
)

# 2. Setup a single swimmer exactly in the middle, pointing right
center_pos = jnp.array([[grid_limit / 2.0, grid_limit / 2.0]])  # Shape (1, 2)
angle = jnp.array([0.0])                                        # Shape (1, )

# Define dipole strengths
sigma_pusher = jnp.array([1.5])   # Positive for Pusher
sigma_puller = jnp.array([-1.5])  # Negative for Puller

_, _, u_grid_pusher_jax = solver(center_pos, angle, sigma_pusher)

_, _, u_grid_puller_jax = solver(center_pos, angle, sigma_puller)

# Convert to standard NumPy for plotting
u_grid_pusher = np.asarray(u_grid_pusher_jax)
u_grid_puller = np.asarray(u_grid_puller_jax)

# Calculate magnitudes: Shape (Nx, Ny)
mag_pusher = np.linalg.norm(u_grid_pusher, axis=0)
mag_puller = np.linalg.norm(u_grid_puller, axis=0)

# %%
# =============================================================================
# PLOTTING
# =============================================================================
fig, axes = plt.subplots(1, 2, figsize=(16, 10), sharex=True, sharey=True, layout='constrained')

# Grid setup (indexing='ij' matches JAX meshing)
x = np.linspace(0, grid_limit, grid_resolution, endpoint=False)
y = np.linspace(0, grid_limit, grid_resolution, endpoint=False)
X, Y = np.meshgrid(x, y, indexing='ij')

# Normalize the colormap (adjust limits if your arrows disappear or blow out)
VMIN = 3e-4
VMAX = 0.7 
norm = mcolors.LogNorm(vmin=VMIN, vmax=VMAX)

# Configuration for the loop
plot_configs = [
    {
        "ax": axes[0], "title": "Pusher", 
        "mag": mag_pusher, "ux": u_grid_pusher[0], "uy": u_grid_pusher[1], 
        "color": '#FF2DAA'
    },
    {
        "ax": axes[1], "title": "Puller", 
        "mag": mag_puller, "ux": u_grid_puller[0], "uy": u_grid_puller[1], 
        "color": '#FF5A36'
    }
]

for cfg in plot_configs:
    ax = cfg["ax"]
    
    # Render heatmap and streamlines (Note the .T transposes for Matplotlib)
    ax.pcolormesh(X.T, Y.T, cfg["mag"].T, cmap='viridis', norm=norm, shading='auto', zorder=0)
    ax.streamplot(X.T, Y.T, cfg["ux"].T, cfg["uy"].T, color='white', density=1.5, 
                  linewidth=1.0, arrowsize=1.2, zorder=1)
    
    # Draw the swimmer at the center
    ax.quiver(center_pos[0, 0], center_pos[0, 1], np.cos(0.0), np.sin(0.0), 
              color=cfg["color"], scale=15, scale_units='width', zorder=5)
    
    # Formatting
    ax.set_title(cfg["title"])
    ax.set_xlim(0, grid_limit)
    ax.set_ylim(0, grid_limit)
    ax.set_aspect('equal')
    ax.set_xlabel(r'$x$')

axes[0].set_ylabel(r'$y$')

# Shared Colorbar
sm = cm.ScalarMappable(cmap='viridis', norm=norm)
sm.set_array([])
cbar = fig.colorbar(sm, ax=axes.ravel().tolist(), pad=0.02, shrink=0.6)
cbar.set_label("Magnitude of velocity")

plt.suptitle("Flow Signature Verification", y=0.93)
plt.savefig(f"flow_signature_abp_couple_stokes.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# #### Self-advection Check

# %%
# On the grid test
grid_resolution = 256
grid_limit = 12.8
dt = 0.1
total_steps = 500  # Running a bit longer to let any potential drift accumulate

# 1. Instantiate the solver
solver = build_quasi2d_stokes_solver(
    Lx=grid_limit, Ly=grid_limit, Lz=grid_limit, 
    Nx=grid_resolution, Ny=grid_resolution, Nz=grid_resolution
)

# 2. Instantiate trajectory generator with NO self-propulsion and NO noise
v0_test = 0.0
Dr_test = 0.0
sigma_test = jnp.array([1.5])  # Use a strong pusher to amplify any errors

generate_trajectory = build_trajectory_generator(
    Lx=grid_limit, Ly=grid_limit, dt=dt, 
    solve_flow_fn=solver, sigmas=sigma_test, 
    v0=v0_test, Dr=Dr_test
)

# 3. Setup a single swimmer exactly in the middle
initial_positions = jnp.array([[grid_limit / 2.0, grid_limit / 2.0]])
initial_angles = jnp.array([0.0])

key = jax.random.PRNGKey(42)

pos_history, angle_history = generate_trajectory(
    initial_positions, initial_angles, num_steps=total_steps, prng_key=key
)

# Convert to NumPy for analysis
pos_history_np = np.asarray(pos_history) # Shape: (total_steps, 1, 2)

# 5. Calculate displacement from the initial position
# Extract the single swimmer's trajectory
x_coords = pos_history_np[:, 0, 0]
y_coords = pos_history_np[:, 0, 1]

# Calculate absolute distance from the starting point at each time step
displacement = np.sqrt((x_coords - x_coords[0])**2 + (y_coords - y_coords[0])**2)
max_disp = np.max(displacement)
print(f"Maximum displacement over {total_steps} steps: {max_disp:.2e}")
# Out:
# Maximum displacement over 500 steps: 0.00e+00

# %%
# Off the grid test
grid_resolution = 256
grid_limit = 12.8
dt = 0.1
total_steps = 500  # Running a bit longer to let any potential drift accumulate

# 1. Instantiate the solver
solver = build_quasi2d_stokes_solver(
    Lx=grid_limit, Ly=grid_limit, Lz=grid_limit, 
    Nx=grid_resolution, Ny=grid_resolution, Nz=grid_resolution
)

# 2. Instantiate trajectory generator with NO self-propulsion and NO noise
v0_test = 0.0
Dr_test = 0.0
sigma_test = jnp.array([1.5])  # Use a strong pusher to amplify any errors

generate_trajectory = build_trajectory_generator(
    Lx=grid_limit, Ly=grid_limit, dt=dt, 
    solve_flow_fn=solver, sigmas=sigma_test, 
    v0=v0_test, Dr=Dr_test
)

# 3. Setup a single swimmer exactly in the middle
initial_positions = jnp.array([[grid_limit / 3.0, grid_limit / 3.0]])
initial_angles = jnp.array([0.0])

key = jax.random.PRNGKey(42)

pos_history, angle_history = generate_trajectory(
    initial_positions, initial_angles, num_steps=total_steps, prng_key=key
)

# Convert to NumPy for analysis
pos_history_np = np.asarray(pos_history) # Shape: (total_steps, 1, 2)

# 5. Calculate displacement from the initial position
# Extract the single swimmer's trajectory
x_coords = pos_history_np[:, 0, 0]
y_coords = pos_history_np[:, 0, 1]

# Calculate absolute distance from the starting point at each time step
displacement = np.sqrt((x_coords - x_coords[0])**2 + (y_coords - y_coords[0])**2)
max_disp = np.max(displacement)
print(f"Maximum displacement over {total_steps} steps with grid resolution of {grid_resolution}: {max_disp:.2e}")
# Out:
# Maximum displacement over 500 steps with grid resolution of 256: 5.61e-02

# %%
# Off the grid test
grid_resolution = 128
grid_limit = 12.8
dt = 0.1
total_steps = 500  # Running a bit longer to let any potential drift accumulate

# 1. Instantiate the solver
solver = build_quasi2d_stokes_solver(
    Lx=grid_limit, Ly=grid_limit, Lz=grid_limit, 
    Nx=grid_resolution, Ny=grid_resolution, Nz=grid_resolution
)

# 2. Instantiate trajectory generator with NO self-propulsion and NO noise
v0_test = 0.0
Dr_test = 0.0
sigma_test = jnp.array([1.5])  # Use a strong pusher to amplify any errors

generate_trajectory = build_trajectory_generator(
    Lx=grid_limit, Ly=grid_limit, dt=dt, 
    solve_flow_fn=solver, sigmas=sigma_test, 
    v0=v0_test, Dr=Dr_test
)

# 3. Setup a single swimmer exactly in the middle
initial_positions = jnp.array([[grid_limit / 3.0, grid_limit / 3.0]])
initial_angles = jnp.array([0.0])

key = jax.random.PRNGKey(42)

pos_history, angle_history = generate_trajectory(
    initial_positions, initial_angles, num_steps=total_steps, prng_key=key
)

# Convert to NumPy for analysis
pos_history_np = np.asarray(pos_history) # Shape: (total_steps, 1, 2)

# 5. Calculate displacement from the initial position
# Extract the single swimmer's trajectory
x_coords = pos_history_np[:, 0, 0]
y_coords = pos_history_np[:, 0, 1]

# Calculate absolute distance from the starting point at each time step
displacement = np.sqrt((x_coords - x_coords[0])**2 + (y_coords - y_coords[0])**2)
max_disp = np.max(displacement)
print(f"Maximum displacement over {total_steps} steps with grid resolution of {grid_resolution}: {max_disp:.2e}")
# Out:
# Maximum displacement over 500 steps with grid resolution of 128: 3.88e-01

# %% [markdown]
# Note on self-advection check: When the swimmer is right on the grid, there's no displacement after 500 steps. There's no
# off-grid interpolation here. Hence, everything except discretisation error is tested here, of which no flaws are found.
#
# For the case of the swimmer being off-grid, there's discretisation error as the velocity of the fluid between grid nodes
# are computed using interpolation. With a grid resolution of 128 x 128, in 1 s (i.e. 10 steps), with a self-propulsion
# velocity of 0.1, the error is around 8%. This is reduced to around 1% at a grid resolution of 256 x 256. This confirms
# that the error is due to discretisation error.
#
# This also looks promising as doubling the resolution drops the error by 6.92, corresponding to a convergence of 2.8
# ($2^{2.8} \approx 6.92$). This shows that convergence can be achieved quickly by increasing grid resolution.

# %% [markdown]
# #### Two-Swimmer Hydrodynamic Scattering Test

# %%
grid_resolution = 256
grid_limit = 12.8
dt = 0.1
total_steps = 800

# 1. Instantiate the true Stokes solver
solver = build_quasi2d_stokes_solver(
    Lx=grid_limit, Ly=grid_limit, Lz=grid_limit, 
    Nx=grid_resolution, Ny=grid_resolution, Nz=grid_resolution
)

# 2. Setup two strong Pushers with deterministic kinematics (no noise)
Dr_scatter = 0.0  # Zero noise to isolate hydrodynamics
sigmas_scatter = jnp.array([1.5, 1.5])  # Two Pushers

generate_trajectory = build_trajectory_generator(
    Lx=grid_limit, Ly=grid_limit, dt=dt, 
    solve_flow_fn=solver, sigmas=sigmas_scatter, 
    Dr=Dr_scatter
)

# 3. Setup Initial Conditions: Swimming towards each other

initial_positions = jnp.array([
    [0.25*grid_limit, 0.0],  # Swimmer 1: Left side
    [0.75*grid_limit, 0.0]  # Swimmer 2: Right side
])

initial_angles = jnp.array([
    0.25*jnp.pi,      # Swimmer 1 pointing upper right
    0.75*jnp.pi    # Swimmer 2 pointing upper left
])

key = jax.random.PRNGKey(42)

# 4. Run the simulation
pos_history, angle_history = generate_trajectory(
    initial_positions, initial_angles, num_steps=total_steps, prng_key=key
)

# Convert to standard NumPy for plotting
pos_history_np = np.asarray(pos_history)
angle_history_np = np.asarray(angle_history)

# %%
fig, ax = plt.subplots(figsize=(12, 10))

# Setup the canvas limits and styling
ax.set_xlim(0, grid_limit)
ax.set_ylim(0, grid_limit)
ax.set_title("Two Pushers Hydrodynamic Scattering")
ax.set_xlabel(r"$x$")
ax.set_ylabel(r"$y$")

# 1. Initialize the empty trail lines
trail1, = ax.plot([], [], color='C0', linewidth=2, alpha=0.5, label='Pusher 1')
trail2, = ax.plot([], [], color='C1', linewidth=2, alpha=0.5, label='Pusher 2')

# 2. Initialize the quiver (arrows) for the swimmers' current positions and orientations
Q = ax.quiver([0, 0], [0, 0], [1, 1], [0, 0], 
              color=['C0', 'C1'], 
              scale=20, scale_units='width', zorder=4)

ax.legend(loc='upper right')

# 3. Define the initialization function for the animator
def init():
    trail1.set_data([], [])
    trail2.set_data([], [])
    Q.set_offsets([[0, 0], [0, 0]])
    Q.set_UVC([0, 0], [0, 0])
    return trail1, trail2, Q

# 4. Define the update function that runs for every frame
def update(frame):
    # Update the trailing lines up to the current frame
    trail1.set_data(pos_history_np[:frame, 0, 0], pos_history_np[:frame, 0, 1])
    trail2.set_data(pos_history_np[:frame, 1, 0], pos_history_np[:frame, 1, 1])
    
    # Update the quiver offsets (current x, y coordinates)
    x_coords = pos_history_np[frame, :, 0]
    y_coords = pos_history_np[frame, :, 1]
    Q.set_offsets(np.c_[x_coords, y_coords])
    
    # Update the quiver directions (cos(theta), sin(theta))
    angles = angle_history_np[frame, :]
    Q.set_UVC(np.cos(angles), np.sin(angles))
    
    return trail1, trail2, Q

# 5. Compile the animation
ani = FuncAnimation(
    fig, update, frames=total_steps,
    init_func=init, blit=True
)

# =============================================================================
# EXPORT TO MP4
# =============================================================================
output_filename = 'two_pushers_hydrodynamic_scattering.mp4'
fps = int(total_steps/10) 

# Write the animation to an MP4 file using the FFmpeg writer
ani.save(output_filename, writer='ffmpeg', fps=fps, dpi=300)

# %% [markdown]
# ### Inclusion of GEM-4 Potential

# %%
class AxisymmetricSwimmers2D:
    def __init__(self, positions, angles, dipole_strengths):
        """
        Initialise N axisymmetric dipole microswimmers in a 2D plane.
    
        Parameters
        ----------
        positions : Array, shape (N, 2)
            (x, y) coordinates of each swimmer
        angles : Array, shape (N, )
            Orientation angle (theta) of each swimmer, measured from the x-axis
        dipole_strengths : Array, shape (N, )
            Scalar dipole strength of each swimmer. 
            Positive for pusher, negative for puller.
        """
        self.positions = jnp.asarray(positions, dtype=jnp.float64)
        self.angles = jnp.asarray(angles, dtype=jnp.float64)
        self.dipole_strengths = jnp.asarray(dipole_strengths, dtype=jnp.float64)

    @property
    def count(self):
        """Returns the number of swimmers in the system"""
        return self.positions.shape[0]

    def update_states(self, new_positions, new_angles):
        """Updates kinematic states. Dipole strengths are assumed constant."""
        self.positions = new_positions
        self.angles = new_angles

# %%
def build_quasi2d_stokes_solver(Lx, Ly, Lz, Nx, Ny, Nz, mu=1.0, eps=0.1, sigma_rep=0.2, eps_rep=0.2):
    """
    Precomputes grids and returns a JIT-compiled function to solve the flow field, 
    incorporating wet GEM-4 steric repulsion.
    
    Parameters
    -----------
    Lx, Ly, Lz : Floats
        Dimension of the simulation domain
    Nx, Ny, Nz : Integers
        Number of grid points in each dimension. 
        Should be powers of two for optimal FFT efficiency.
    mu : Float
        Dynamic viscosity
    eps : Float
        Size of Gaussian blob
    sigma_rep : Float
        Length scale of the GEM-4 repulsive potential
    eps_rep: Float
        Strength of the GEM-4 repulsive potential

    Returns
    --------
    solve_flow : JIT-compiled function
        A function to calculate the velocity field of the fluid
    """
    dx, dy, dz = Lx / Nx, Ly / Ny, Lz / Nz
    z_mid = Lz / 2.0
    
    x = jnp.linspace(0, Lx, Nx, endpoint=False)
    y = jnp.linspace(0, Ly, Ny, endpoint=False)
    z = jnp.linspace(0, Lz, Nz, endpoint=False)
    X, Y, Z = jnp.meshgrid(x, y, z, indexing='ij')
    
    kx = 2 * jnp.pi * jnp.fft.fftfreq(Nx, d=dx)
    ky = 2 * jnp.pi * jnp.fft.fftfreq(Ny, d=dy)
    kz = 2 * jnp.pi * jnp.fft.fftfreq(Nz, d=dz)
    KX, KY, KZ = jnp.meshgrid(kx, ky, kz, indexing='ij')
    
    K2 = KX**2 + KY**2 + KZ**2
    K2_safe = jnp.where(K2 == 0.0, 1.0, K2)

    def _single_swimmer_force(pos_2d, theta, sigma, rep_force):
        """
        Compute the force density exerted by a single swimmer, combining both 
        the active force dipole and the transient repulsive point force.
    
        Parameters
        -----------
        pos_2d : Array, shape (2, )
            (x, y) coordinates of the swimmer
        theta : Float
            Orientation of the swimmer with respect to the x-axis
        sigma : Float
            Dipole strength, positive for pusher, negative for puller.
        rep_force : Array, shape (2, )
            x and y-components of the force exerted by the swimmer on the fluid 
            due to steric repulsion from all other neighbours
        Returns
        --------
        force_density : Array, shape (3, Nx, Ny, Nz)
            Force density field due to the swimmer
        """
        px, py = jnp.cos(theta), jnp.sin(theta)
        M_xx, M_xy, M_yy = sigma * px * px, sigma * px * py, sigma * py * py
        
        rx, ry, rz = X - pos_2d[0], Y - pos_2d[1], Z - z_mid

        # Minimum Image Convention for periodic boundaries
        rx -= Lx * jnp.round(rx / Lx)
        ry -= Ly * jnp.round(ry / Ly)
        rz -= Lz * jnp.round(rz / Lz)
        
        r2 = rx**2 + ry**2 + rz**2
        
        # Calculate the regularizing Gaussian blob (phi_g)
        prefactor = 1.0 / ((2.0 * jnp.pi)**1.5 * eps**3)
        phi_g = prefactor * jnp.exp(-r2 / (2.0 * eps**2))
        
        # 1. Active Dipole Force Field
        f_active_x = (M_xx * rx + M_xy * ry) * phi_g / (eps**2)
        f_active_y = (M_xy * rx + M_yy * ry) * phi_g / (eps**2)
        
        # 2. Steric Repulsive Force Field (Mapped to grid via Immersed Boundary)
        f_rep_x = rep_force[0] * phi_g
        f_rep_y = rep_force[1] * phi_g
        
        # Combine forces
        f_x = f_active_x + f_rep_x
        f_y = f_active_y + f_rep_y
        f_z = jnp.zeros_like(f_x)

        force_density = jnp.stack([f_x, f_y, f_z], axis=0)
        
        return force_density

    @jax.jit
    def solve_flow(positions, angles, sigmas):
        """
        Compute the velocity flow field due to active pumping and steric repulsion of N microswimmers.
        GEM-4 potential is used to compute steric repulsion.
        Linear interpolation is used to find velocity away from grid points.
    
        Parameters
        -----------
        positions : Array, shape (N, 2)
            (x, y) coordinates of all swimmers
        angles : Array, shape (N, )
            Orientations of all swimmers with respect to the x-axis
        sigmas : Array, shape (N, )
            Dipole strength of all swimmers, positive for pusher, negative for puller.
    
        Returns
        --------
        u_fluid : Array, shape (N, 2)
            The linear velocity experienced by each swimmer due to background flow.
        Omega_fluid : Array, shape (N, )
            The angular velocity experienced by each swimmer due to background flow.
        u_grid_2d : Array, shape (2, Nx, Ny)
            The velocity flow field due to all swimmers at the grid points.
        """
        # Vectorized GEM-4 Pairwise Repulsion Calculation
        dx_pair = positions[:, 0, None] - positions[None, :, 0]
        dy_pair = positions[:, 1, None] - positions[None, :, 1]
        
        # Minimum Image Convention
        dx_pair -= Lx * jnp.round(dx_pair / Lx)
        dy_pair -= Ly * jnp.round(dy_pair / Ly)
        
        dist_sq = dx_pair**2 + dy_pair**2
        safe_dist_sq = jnp.where(dist_sq == 0.0, 1.0, dist_sq)
        
        # GEM-4 Force Magnitude: F = 4 * eps * (r^3 / sigma^4) * exp(-(r/sigma)^4)
        r_over_sig_4 = safe_dist_sq**2 / sigma_rep**4
        force_div_r = 4.0 * eps_rep * (safe_dist_sq / sigma_rep**4) * jnp.exp(-r_over_sig_4)
        
        # Mask self-interactions (diagonal)
        force_div_r = jnp.where(dist_sq == 0.0, 0.0, force_div_r)
        
        # Net repulsive force vector on each swimmer i
        net_rep_fx = jnp.sum(force_div_r * dx_pair, axis=1)
        net_rep_fy = jnp.sum(force_div_r * dy_pair, axis=1)
        net_rep_forces = jnp.stack([net_rep_fx, net_rep_fy], axis=-1)
        # -----------------------------------------------------------

        def add_swimmer_force(accumulated_force, i):
            """
            Calculates force for swimmer i and adds it to the running total.
    
            Parameters
            -----------
            accumulated_force : Array, shape (3, Nx, Ny, Nz)
                Total force on the fluid due to all microswimmers accounted for thus far 
                (index 0 to i-1) at the current iteration.
            i : Integer
                Index of the swimmer to be accounted for in the current iteration.
        
            Returns
            --------
            new_force : Array, shape (3, Nx, Ny, Nz)
                The updated accumulated force after considering swimmer of index i.
            None : This is supposed to be the history of accumulated force. Not needed 
            here. Left `None` for memory management.
            """
            new_force = accumulated_force + _single_swimmer_force(
                positions[i], angles[i], sigmas[i], net_rep_forces[i]
            )
            return new_force, None

        # Initialize an empty grid of zeros
        initial_force_grid = jnp.zeros((3, Nx, Ny, Nz))
        
        # Accumulate forces
        total_force, _ = jax.lax.scan(
            add_swimmer_force, 
            initial_force_grid, 
            jnp.arange(positions.shape[0])
        )
        
        # FFT Fluid Solver 
        F_hat_x = jnp.fft.fftn(total_force[0])
        F_hat_y = jnp.fft.fftn(total_force[1])
        F_hat_z = jnp.fft.fftn(total_force[2])
        
        k_dot_F_hat = KX * F_hat_x + KY * F_hat_y + KZ * F_hat_z
        
        U_hat_x = (F_hat_x - KX * k_dot_F_hat / K2_safe) / (mu * K2_safe)
        U_hat_y = (F_hat_y - KY * k_dot_F_hat / K2_safe) / (mu * K2_safe)
        
        U_hat_x = U_hat_x.at[0, 0, 0].set(0.0)
        U_hat_y = U_hat_y.at[0, 0, 0].set(0.0)
        
        Vort_hat_z = 1j * KX * U_hat_y - 1j * KY * U_hat_x
        
        u_x_3d = jnp.fft.ifftn(U_hat_x).real
        u_y_3d = jnp.fft.ifftn(U_hat_y).real
        vort_z_3d = jnp.fft.ifftn(Vort_hat_z).real
        
        # Slice at mid-plane
        z_idx = Nz // 2
        u_x_2d = u_x_3d[:, :, z_idx]
        u_y_2d = u_y_3d[:, :, z_idx]
        vort_z_2d = vort_z_3d[:, :, z_idx]

        # Interpolate fluid velocity back to particle positions
        x_idx = positions[:, 0] / dx
        y_idx = positions[:, 1] / dy
        coords = jnp.stack([x_idx, y_idx], axis=0)
        
        u_fluid_x = jndi.map_coordinates(u_x_2d, coords, order=1, mode='wrap')
        u_fluid_y = jndi.map_coordinates(u_y_2d, coords, order=1, mode='wrap')
        vort_fluid_z = jndi.map_coordinates(vort_z_2d, coords, order=1, mode='wrap')
        
        u_fluid = jnp.stack([u_fluid_x, u_fluid_y], axis=-1)
        omega_fluid = 0.5 * vort_fluid_z
        u_grid_2d = jnp.stack([u_x_2d, u_y_2d], axis=0)

        return u_fluid, omega_fluid, u_grid_2d

    return solve_flow

# %%
def build_trajectory_generator(Lx, Ly, dt, solve_flow_fn, sigmas, v0=0.1, Dr=0.01):
    """
    Returns a JIT-compiled function that simulates swimmer trajectories over time
    using active self-propulsion, rotational diffusion, AND hydrodynamic coupling.

    Parameters
    -----------
    Lx, Ly : Floats
        Dimensions of the simulation domain
    dt : Float
        Time-step
    solve_flow_fn : JIT-compiled function
        Returns linear and angular velocity of a rigid particle due to background flow
    sigmas : Array, shape (N, )
        Dipole strength of all swimmers, positive for pusher, negative for puller.
    v0 : Float
        Self-propulsion velocity of all swimmers (share the same value)
    Dr : Float
        Rotational diffusivity of all swimmers (share the same value)

    Returns
    --------
    wrapper_simulation : JIT-compiled function
        A function which computes the trajectory (position and angle) of 
        all swimmers over time.
    """
    
    @jax.jit(static_argnames=['num_steps'])
    def wrapper_simulation(initial_positions, initial_angles, num_steps, prng_key):
        """
        The function which computes the trajectory (positions and orientations) of 
        all swimmers over time.
    
        Parameters
        -----------
        initial_positions : Array, shape (N, 2)
            Initial (x, y) coordinates of all swimmers
        initial_angles : Array, shape (N, )
            Initial orientation, as measured from x-axis, of all swimmers
        num_steps : Integer
            Number of timesteps of the simulation
        prng_key: jax.Array
            Starting pseudo-random number generator key
    
        Returns
        --------
        trajectory : tuple of 2 elements
            1st element is the history of positions, a JAX array of shape 
            (num_steps, N, 2).
            2nd element is the history of orientations, a JAX array of shape 
            (num_steps, N).
        """
        def scan_step(carry, _):
            """
            Helper function to be used as an argument for jax.lax.scan. This function 
            will be iterated to update the positions and angles of the swimmers.
        
            Parameters
            -----------
            carry : tuple
                Current (x, y) positions of all swimmers, current orientation of all 
                swimmers, and current random number generator key.
        
            Returns
            --------
            next_carry : tuple
                The value of carry to be used in the next iteration of scan_step.
            outputs : tuple
                The data from the current timestep to be saved, which is (x, y) 
                positions and orientation of all swimmers.
            """
            pos, current_angles, key = carry
            
            # The fluid flow now inherently includes the repulsive steric forces
            u_fluid, omega_fluid, _ = solve_flow_fn(pos, current_angles, sigmas)
            
            # 1. Update positions (Active Propulsion + Background Flow)
            px = jnp.cos(current_angles)
            py = jnp.sin(current_angles)
            p = jnp.stack([px, py], axis=-1)
            
            next_pos = pos + (v0 * p + u_fluid) * dt
            next_pos = next_pos % jnp.array([Lx, Ly])
            
            # 2. Update angles
            key, subkey = jax.random.split(key)
            noise = jax.random.normal(subkey, shape=current_angles.shape)
            
            next_angles = current_angles + jnp.sqrt(2.0 * Dr * dt) * noise + omega_fluid * dt
            next_angles = next_angles % (2.0 * jnp.pi)
            
            next_carry = (next_pos, next_angles, key)
            outputs = (pos, current_angles)
            return next_carry, outputs

        init_state = (initial_positions, initial_angles, prng_key)
        _, trajectory = jax.lax.scan(scan_step, init_state, None, length=num_steps)
        
        return trajectory

    return wrapper_simulation

# %%
grid_resolution = 256
grid_limit = 12.8
dt = 0.1
total_steps = 1000

# 1. Instantiate the coupled solvers
solver = build_quasi2d_stokes_solver(
    Lx=grid_limit, Ly=grid_limit, Lz=grid_limit, 
    Nx=grid_resolution, Ny=grid_resolution, Nz=grid_resolution
)

sigmas_array = jnp.array([-1.0, -1.0, 1.5]) 
generate_trajectory = build_trajectory_generator(
    Lx=grid_limit, Ly=grid_limit, dt=dt, 
    solve_flow_fn=solver, sigmas=sigmas_array
)

# 2. Define 3 swimmers
positions = [
    [1.0, 3.0],
    [6.0, 10.0],
    [2.2, 8.2]
]
angles = [0.0, np.pi, np.pi/4.0]
swimmers = AxisymmetricSwimmers2D(positions, angles, sigmas_array)

# Initialize JAX random state for Brownian noise
key = jax.random.PRNGKey(42)

# =============================================================================
# TRAJECTORY GENERATION
# =============================================================================
print("Generating trajectory...")
pos_history, angle_history = generate_trajectory(
    swimmers.positions, swimmers.angles, num_steps=total_steps, prng_key=key
)

# Convert JAX trajectory arrays to NumPy immediately
pos_history_np = np.asarray(pos_history)
angle_history_np = np.asarray(angle_history)

# =============================================================================
# FLOW FIELD POST-PROCESSING
# =============================================================================
u_history_list = []

for t in range(total_steps):
    # Extract the full 2D grid from the 3rd output
    _, _, u_grid_jax = solver(pos_history_np[t], angle_history_np[t], swimmers.dipole_strengths)
    u_history_list.append(np.asarray(u_grid_jax))

    if t % 10 == 0:
        print(f"Calculating flow field at iteration {t:d}")

# Shape: (num_steps, 2, Nx, Ny)
u_history_numpy = np.stack(u_history_list)

# Shape: (num_steps, Nx, Ny)
u_history_mag = np.linalg.norm(u_history_numpy, axis=1)
# Out:
# Generating trajectory...
# Calculating flow field at iteration 0
# Calculating flow field at iteration 10
# Calculating flow field at iteration 20
# Calculating flow field at iteration 30
# Calculating flow field at iteration 40
# Calculating flow field at iteration 50
# Calculating flow field at iteration 60
# Calculating flow field at iteration 70
# Calculating flow field at iteration 80
# Calculating flow field at iteration 90
# Calculating flow field at iteration 100
# Calculating flow field at iteration 110
# Calculating flow field at iteration 120
# Calculating flow field at iteration 130
# Calculating flow field at iteration 140
# Calculating flow field at iteration 150
# Calculating flow field at iteration 160
# Calculating flow field at iteration 170
# Calculating flow field at iteration 180
# Calculating flow field at iteration 190
# Calculating flow field at iteration 200
# Calculating flow field at iteration 210
# Calculating flow field at iteration 220
# Calculating flow field at iteration 230
# Calculating flow field at iteration 240
# Calculating flow field at iteration 250
# Calculating flow field at iteration 260
# Calculating flow field at iteration 270
# Calculating flow field at iteration 280
# Calculating flow field at iteration 290
# Calculating flow field at iteration 300
# Calculating flow field at iteration 310
# Calculating flow field at iteration 320
# Calculating flow field at iteration 330
# Calculating flow field at iteration 340
# Calculating flow field at iteration 350
# Calculating flow field at iteration 360
# Calculating flow field at iteration 370
# Calculating flow field at iteration 380
# Calculating flow field at iteration 390
# Calculating flow field at iteration 400
# Calculating flow field at iteration 410
# Calculating flow field at iteration 420
# Calculating flow field at iteration 430
# Calculating flow field at iteration 440
# Calculating flow field at iteration 450
# Calculating flow field at iteration 460
# Calculating flow field at iteration 470
# Calculating flow field at iteration 480
# Calculating flow field at iteration 490
# Calculating flow field at iteration 500
# Calculating flow field at iteration 510
# Calculating flow field at iteration 520
# Calculating flow field at iteration 530
# Calculating flow field at iteration 540
# Calculating flow field at iteration 550
# Calculating flow field at iteration 560
# Calculating flow field at iteration 570
# Calculating flow field at iteration 580
# Calculating flow field at iteration 590
# Calculating flow field at iteration 600
# Calculating flow field at iteration 610
# Calculating flow field at iteration 620
# Calculating flow field at iteration 630
# Calculating flow field at iteration 640
# Calculating flow field at iteration 650
# Calculating flow field at iteration 660
# Calculating flow field at iteration 670
# Calculating flow field at iteration 680
# Calculating flow field at iteration 690
# Calculating flow field at iteration 700
# Calculating flow field at iteration 710
# Calculating flow field at iteration 720
# Calculating flow field at iteration 730
# Calculating flow field at iteration 740
# Calculating flow field at iteration 750
# Calculating flow field at iteration 760
# Calculating flow field at iteration 770
# Calculating flow field at iteration 780
# Calculating flow field at iteration 790
# Calculating flow field at iteration 800
# Calculating flow field at iteration 810
# Calculating flow field at iteration 820
# Calculating flow field at iteration 830
# Calculating flow field at iteration 840
# Calculating flow field at iteration 850
# Calculating flow field at iteration 860
# Calculating flow field at iteration 870
# Calculating flow field at iteration 880
# Calculating flow field at iteration 890
# Calculating flow field at iteration 900
# Calculating flow field at iteration 910
# Calculating flow field at iteration 920
# Calculating flow field at iteration 930
# Calculating flow field at iteration 940
# Calculating flow field at iteration 950
# Calculating flow field at iteration 960
# Calculating flow field at iteration 970
# Calculating flow field at iteration 980
# Calculating flow field at iteration 990

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 10))

x = np.linspace(0, grid_limit, grid_resolution, endpoint=False)
y = np.linspace(0, grid_limit, grid_resolution, endpoint=False)
X, Y = np.meshgrid(x, y, indexing='ij')

VMIN = 5e-4
VMAX = 0.8
norm = mcolors.LogNorm(vmin=VMIN, vmax=VMAX)
sm = cm.ScalarMappable(cmap='viridis', norm=norm)
sm.set_array([])
fig.colorbar(sm, ax=ax, pad=0.02, shrink=0.6, label="Magnitude of velocity")

def update(frame):
    ax.clear()
    
    # Static formatting
    ax.set_xlim(0, grid_limit)
    ax.set_ylim(0, grid_limit)
    ax.set_xlabel(r'$x$')
    ax.set_ylabel(r'$y$')
    ax.set_aspect('equal')
    ax.set_title(f"ABP in Stokes Flow with GEM-4 Repulsion | Time Step: {dt*frame:.1f}")
    
    u_mag_t = u_history_mag[frame]
    u_x_t = u_history_numpy[frame, 0]
    u_y_t = u_history_numpy[frame, 1]
    
    # Note: Because of indexing='ij', we transpose (.T) for Matplotlib
    ax.pcolormesh(X.T, Y.T, u_mag_t.T, cmap='viridis', norm=norm, shading='auto', zorder=0)
    ax.streamplot(X.T, Y.T, u_x_t.T, u_y_t.T, color='white', density=1.2, 
                  linewidth=1.0, arrowsize=1.2, zorder=1)
    
    legend_tracker = {"Pusher": False, "Puller": False}
    
    for i in range(swimmers.count):
        sigma = swimmers.dipole_strengths[i]
        current_angle = angle_history_np[frame, i]
        current_pos_x = pos_history_np[frame, i, 0]
        current_pos_y = pos_history_np[frame, i, 1]
        
        px = np.cos(current_angle) * np.abs(sigma)
        py = np.sin(current_angle) * np.abs(sigma)
        
        if sigma > 0:
            color = '#FF2DAA'
            swimmer_type = "Pusher"
        else:
            color = '#FF5A36'
            swimmer_type = "Puller"

        quiver_label = swimmer_type if not legend_tracker[swimmer_type] else "_"
        legend_tracker[swimmer_type] = True
        
        ax.quiver(
            current_pos_x, current_pos_y, 
            px, py, 
            color=color, 
            scale=15,
            scale_units='width',
            zorder=5,
            label=quiver_label
        )
        
    ax.legend(loc="upper left", bbox_to_anchor=(1, 1.02))

ani = FuncAnimation(fig, update, frames=total_steps, interval=50, blit=False)
output_filename = "abp_hydrodynamic_gem4.mp4"
ani.save(output_filename, writer='ffmpeg', fps=100, dpi=300)

# %% [markdown]
# #### Head-on Collision Test

# %%
# ---------------------------------------------------------
# 1. Define Domain and Parameters
# ---------------------------------------------------------
Lx, Ly, Lz = 10.0, 10.0, 10.0
Nx, Ny, Nz = 32, 32, 32  # Small grid for a fast test
dt = 0.05
num_steps = 400

v0 = 0.5         # High enough propulsion to force a fast collision
Dr = 0.0         # ZERO rotational diffusion to ensure a perfect head-on strike
sigma_rep = 0.2  # Length scale of the repulsion
eps_rep = 1.0    # Relatively strong repulsion to make the bounce obvious

# ---------------------------------------------------------
# 2. Initial Conditions: Head-On Setup
# ---------------------------------------------------------
# Swimmer 0 starts at x=3, y=5, pointing right (angle = 0)
# Swimmer 1 starts at x=7, y=5, pointing left (angle = pi)
initial_positions = jnp.array([
    [3.0, 5.0], 
    [7.0, 5.0]
])
initial_angles = jnp.array([0.0, jnp.pi])

# Turn off the active dipole completely to purely test steric repulsion
sigmas = jnp.array([0.0, 0.0]) 

# ---------------------------------------------------------
# 3. Build Functions
# ---------------------------------------------------------
solve_flow_fn = build_quasi2d_stokes_solver(
    Lx, Ly, Lz, Nx, Ny, Nz, 
    mu=1.0, eps=0.1, sigma_rep=sigma_rep, eps_rep=eps_rep
)

# Using your current build_trajectory_generator that takes constant sigmas
simulator = build_trajectory_generator(
    Lx, Ly, dt, solve_flow_fn, sigmas, v0=v0, Dr=Dr
)

# ---------------------------------------------------------
# 4. Run Simulation
# ---------------------------------------------------------
print("Running head-on collision test...")
key = jax.random.PRNGKey(0)
pos_history, angle_history = simulator(initial_positions, initial_angles, num_steps, key)

# %%
# ---------------------------------------------------------
# 5. Plot the Results
# ---------------------------------------------------------
time_axis = jnp.arange(num_steps) * dt

# Extract the X-coordinates of both swimmers over time
x_coords_swimmer_0 = pos_history[:, 0, 0]
x_coords_swimmer_1 = pos_history[:, 1, 0]

plt.figure(figsize=(8, 5))
plt.plot(time_axis, x_coords_swimmer_0, label="Swimmer 0 (Moving Right \u2192)", lw=2, color='blue')
plt.plot(time_axis, x_coords_swimmer_1, label="Swimmer 1 (Moving Left \u2190)", lw=2, color='red')

# Plot the center line where they should meet
plt.axhline(y=5.0, color='gray', linestyle='--', alpha=0.5, label="Collision Center (x=5.0)")

plt.title("Head-On Collision Test (GEM-4 Steric Repulsion)")
plt.xlabel("Time")
plt.ylabel("X-Coordinate")
plt.legend()
plt.grid(True)
plt.show()

# ---------------------------------------------------------
# 6. Sanity Check Console Output
# ---------------------------------------------------------
# Calculate the minimum distance achieved between their centers
min_distance = jnp.min(x_coords_swimmer_1 - x_coords_swimmer_0)
print(f"Target collision radius (\u03c3_rep): {sigma_rep}")
print(f"Minimum center-to-center distance reached: {min_distance:.4f}")

if min_distance > 0.05:
    print("SUCCESS: The swimmers collided and repelled each other safely without crashing!")
else:
    print("WARNING: The swimmers overlapped too much. You may need to increase eps_rep or decrease dt.")
